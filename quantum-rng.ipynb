# %%
pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies
from qiskit.circuit import Parameter, QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.primitives import StatevectorSampler

# %%
# Initiate registers for our quantum computer
quantum_reg = QuantumRegister(1)
classical_reg = ClassicalRegister(1)

# %%
# Initiate the quantum circuits
quantum_circ = QuantumCircuit(quantum_reg, classical_reg)

# %% [markdown]
# So like, I first need to set up the "quantum computer"
# honestly, just from doing this, I get reminded that I have
# not yet mastered computer architecture and organization

# %% [markdown]
# The end goal here is a Quantum RNG,
# which utilizes the superposition of quantum bits
# in generating a random number.
#
# Perhaps, I will also need to code the quantum interference
# so that I could control the state vector for the quantum computer
# I believe the state vector, is where all the quantum mechanics occur.
#
# So, I will also need to implement a data structure that can hold the
# randomized number generated by the superposition of the quantum bits
# which was locked on to by the quantum interference code.
#
# I may need to watch a course first, theoretical one.
